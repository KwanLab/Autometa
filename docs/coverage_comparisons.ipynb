# %% [markdown]
# # Coverage calculations comparison with SPAdes coverage
#
# SPAdes coverages output in the contig header ID seem to differ from the calculated coverage using `samtools` and `bedtools`.
#
# The general coverage calculation as described initially from `contig_coverage_from_bedtools.pl` is as follows:
#
# coverage = sum(coverage-depth * bases w/coverage-depth) / sum(bases w/coverage-depth)

# %%
import plotly.graph_objects as go
from chart_studio.plotly import plot, iplot
from plotly.subplots import make_subplots
import numpy as np

# %%
import pandas as pd
cov = '../tests/data/comparisons.cov.tsv'
df = pd.read_csv(cov, sep='\t')
df.head()
# Out:
#                                contig  bedtools_coverage spades_coverage
# 0  NODE_1000_length_15201_cov_224.564         397.993750         224.564
# 1  NODE_1001_length_15189_cov_223.754         398.305221         223.754
# 2  NODE_1002_length_15170_cov_223.896         398.799473         223.896
# 3  NODE_1003_length_15161_cov_224.737         399.037794         224.737
# 4  NODE_1004_length_15148_cov_223.915         399.378466         223.915

# %%
df = df[df.spades_coverage != 'genome']
df.spades_coverage = df.spades_coverage.astype('float64')
df.head()
# Out:
#                                contig  bedtools_coverage  spades_coverage
# 0  NODE_1000_length_15201_cov_224.564         397.993750          224.564
# 1  NODE_1001_length_15189_cov_223.754         398.305221          223.754
# 2  NODE_1002_length_15170_cov_223.896         398.799473          223.896
# 3  NODE_1003_length_15161_cov_224.737         399.037794          224.737
# 4  NODE_1004_length_15148_cov_223.915         399.378466          223.915

# %%
df = df.assign(cov_diff=lambda x: abs(x.bedtools_coverage - x.spades_coverage))
df.head()
# Out:
#                                contig  bedtools_coverage  spades_coverage  \
# 0  NODE_1000_length_15201_cov_224.564         397.993750          224.564
# 1  NODE_1001_length_15189_cov_223.754         398.305221          223.754
# 2  NODE_1002_length_15170_cov_223.896         398.799473          223.896
# 3  NODE_1003_length_15161_cov_224.737         399.037794          224.737
# 4  NODE_1004_length_15148_cov_223.915         399.378466          223.915
#
#      cov_diff
# 0  173.429750
# 1  174.551221
# 2  174.903473
# 3  174.300794
# 4  175.463466

# %%
df.sort_values(by=['bedtools_coverage', 'spades_coverage'], inplace=True)
df.head(12)
# Out:
#                                 contig  bedtools_coverage  spades_coverage  \
# 2694    NODE_3437_length_105_cov_45.64           3.000000          45.6400
# 2673  NODE_3411_length_148_cov_216.581           8.428571         216.5810
# 2689  NODE_3428_length_120_cov_413.938          22.558333         413.9380
# 2692  NODE_3432_length_111_cov_145.643          23.504505         145.6430
# 2584  NODE_3327_length_225_cov_22.2353          30.000000          22.2353
# 2669  NODE_3407_length_153_cov_625.765          33.084967         625.7650
# 2675  NODE_3413_length_146_cov_110.374          36.726027         110.3740
# 2527  NODE_3276_length_249_cov_350.356          41.396761         350.3560
# 2691  NODE_3431_length_111_cov_234.304          41.981982         234.3040
# 2693  NODE_3434_length_108_cov_453.679          45.518519         453.6790
# 2655  NODE_3395_length_172_cov_1356.68          58.247059        1356.6800
# 2480  NODE_3233_length_271_cov_43.7222          62.269373          43.7222
#
#          cov_diff
# 2694    42.640000
# 2673   208.152429
# 2689   391.379667
# 2692   122.138495
# 2584     7.764700
# 2669   592.680033
# 2675    73.647973
# 2527   308.959239
# 2691   192.322018
# 2693   408.160481
# 2655  1298.432941
# 2480    18.547173

# %%
bedcovs = df.bedtools_coverage.tolist()
spadescovs = df.spades_coverage.tolist()
cov_diffs = df.cov_diff.tolist()
display(df['cov_diff'].describe())
# Out:
# count    3425.000000
# mean      165.430325
# std       103.433452
# min         0.209329
# 25%       155.523854
# 50%       171.699454
# 75%       174.909931
# max      2608.847161
# Name: cov_diff, dtype: float64

# %%
# fig = go.Figure()
fig = make_subplots(rows=2)

# %%
fig.add_trace(go.Scatter(y=bedcovs, name='bedtools coverage'), row=1, col=1)
fig.add_trace(go.Scatter(y=spadescovs, name='SPAdes k-mer coverage'), row=1, col=1)
fig.add_trace(go.Scatter(y=cov_diffs, name='coverage difference'), row=2, col=1)
fig.show()
# Out:
# <div>
#
#
#             <div id="18cefb1f-53a1-4c9c-bf6f-6ebf32763598" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18cefb1f-53a1-4c9c-bf6f-6ebf32763598")) {
#                     Plotly.newPlot(
#                         '18cefb1f-53a1-4c9c-bf6f-6ebf32763598',
#                         [{"name": "bedtools coverage", "type": "scatter", "xaxis": "x", "y": [3.0, 8.428571428571429, 22.55833333333333, 23.504504504504503, 30.0, 33.08496732026144, 36.72602739726028, 41.39676113360324, 41.98198198198198, 45.518518518518526, 58.24705882352941, 62.26937269372694, 63.058035714285715, 64.96519721577727, 65.78125, 67.86220472440945, 68.83333333333333, 69.99152542372882, 70.68345323741008, 72.00704225352112, 72.48148148148148, 80.20766773162941, 82.44621513944223, 85.73469387755101, 89.82889733840305, 91.71140939597315, 92.15352697095436, 95.416, 96.49659863945578, 101.11111111111113, 102.45901639344262, 102.63694267515922, 109.05202312138726, 110.32388663967613, 119.94117647058823, 121.25757575757576, 124.86511627906977, 125.31205673758863, 126.87124463519314, 127.5530303030303, 131.6014492753623, 132.5851851851852, 133.50301204819277, 134.70523415977962, 137.7218045112782, 138.1578947368421, 144.56338028169012, 145.32835820895522, 147.05384615384614, 147.63309352517985, 147.88030888030892, 148.15360501567397, 149.1584905660377, 150.6064814814815, 151.43939393939394, 156.20997375328085, 157.4468085106383, 157.52